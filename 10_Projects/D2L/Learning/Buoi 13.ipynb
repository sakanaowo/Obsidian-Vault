# %% [markdown]
# 3. Tại sao không dùng test set để chọn hyperparams
# - mô hình sẽ fit theo test set -> overfit
# -
#
# 5. Tăng model complexity -> training error luôn giảm nhưng có thể gặp tình trạng genealization error tăng?
# - Khi complexity quá cao -> model học luôn cả noise -> tăng variance
# -> train loss giảm nhưng val loss không hoặc tăng -> generalization gap mở rộng
